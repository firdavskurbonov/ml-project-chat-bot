# %% [markdown]
# # What is Chatbot?

# %% [markdown]
# A chatbot is an intelligent piece of software that is capable of communicating and performing actions similar to a human. Chatbots are used a lot in customer interaction, marketing on social network sites and instantly messaging the client. There are two basic types of chatbot models based on how they are built; Retrieval based and Generative based models.

# %% [markdown]
# ## 1. Retrieval based Chatbots
# A retrieval-based chatbot uses predefined input patterns and responses. It then uses some type of heuristic approach to select the appropriate response. It is widely used in the industry to make goal-oriented chatbots where we can customize the tone and flow of the chatbot to drive our customers with the best experience.
#
# ## 2. Generative based Chatbots
# Generative models are not based on some predefined responses.
#
# They are based on seq 2 seq neural networks. It is the same idea as machine translation. In machine translation, we translate the source code from one language to another language but here, we are going to transform input into an output. It needs a large amount of data and it is based on Deep Neural networks.

# %% [markdown]
# ## About the Python Project – Chatbot
# In this Python project with source code, I am going to build a chatbot using deep learning techniques. The chatbot will be trained on the dataset which contains categories (intents), pattern and responses. We use a special recurrent neural network (LSTM) to classify which category the user’s message belongs to and then we will give a random response from the list of responses.
#
# Let’s create a retrieval based chatbot using NLTK, Keras, Python, etc.
#
# The dataset we will be using ‘intents.json’. This is a JSON file that contains the patterns we need to find and the responses we want to return to the user.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#pip install tensorflow --user

# %%
#pip install keras --user

# %%
#pip install pickle --user

# %%
#pip install nltk --user

# %% [markdown]
# ## How to Make Chatbot in Python
# Now we are going to build the chatbot using Python but first, let us see the file structure and the type of files

# %% [markdown]
# - Intents.json – The data file which has predefined patterns and responses.<br/>
# - train_chatbot.py – In this Python file, we wrote a script to build the model and train our chatbot.<br/>
# - Words.pkl – This is a pickle file in which we store the words Python object that contains a list of our vocabulary.<br/>
# - Classes.pkl – The classes pickle file contains the list of categories.<br/>
# - Chatbot_model.h5 – This is the trained model that contains information about the model and has weights of the neurons.<br/>
# - Chatgui.py – This is the Python script in which we implemented GUI for our chatbot. Users can easily interact with the bot.<br/>
#
# **Here are the 5 steps to create a chatbot in Python from scratch:**<br/>
#
# - Import and load the data file<br/>
# - Preprocess data<br/>
# - Create training and testing data<br/>
# - Build the model<br/>
# - Predict the response<br/>

# %% [markdown]
# **1. Import and load the data file**
#
# We import the necessary packages for our chatbot and initialize the variables we will use in our project.
#
# The data file is in JSON format so we used the json package to parse the JSON file into Python.

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np

import tensorflow as tf
from tensorflow import keras

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents_tj_ru.json', encoding="utf8").read()
intents = json.loads(data_file)

# %% [markdown]
# This is how our intents.json file looks like.

# %%
intents
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['Hi there',
#     'How are you',
#     'Is anyone there?',
#     'Hey',
#     'Hola',
#     'Hello',
#     'Good day'],
#    'responses': ['Hello, thanks for asking',
#     'Good to see you again',
#     'Hi there, how can I help?'],
#    'context': ['']},
#   {'tag': 'привет',
#    'patterns': ['Привет',
#     'Здравствуй',
#     'Здравствуйте',
#     'Эй',
#     'Есть кто нибудь?',
#     'Алло',
#     'Тук-тук'],
#    'responses': ['Привет, спасибо что спрашиваете',
#     'Рад вас видеть',
#     'Привет, чем могу помочь?'],
#    'context': ['']},
#   {'tag': 'салом',
#    'patterns': ['Салом',
#     'Саломалейкум',
#     'Чи хел?',
#     'Ҳей',
#     'Ягон кас хаст?',
#     'Алло',
#     'Ассалому алейкум'],
#    'responses': ['Салом, ба шумо чи хизмат кунем?',
#     'Мо аз дидани шумо хушҳол шудем',
#     'Салом, чи тавр ёри расонем?'],
#    'context': ['']},
#   {'tag': 'goodbye',
#    'patterns': ['Bye',
#     'See you later',
#     'Goodbye',
#     'Nice chatting to you, bye',
#     'Till next time'],
#    'responses': ['See you!', 'Have a nice day', 'Bye! Come back again soon.'],
#    'context': ['']},
#   {'tag': 'пока',
#    'patterns': ['До свидания',
#     'Пока',
#     'Увидимся позже',
#     'Приятно было пообщаться',
#     'До скорой встречи'],
#    'responses': ['Пока!', 'Хорошего дня вам', 'До свидания!'],
#    'context': ['']},
#   {'tag': 'хайр',
#    'patterns': ['Хайр',
#     'Хай',
#     'То боздид',
#     'Хеле мамнун шудам',
#     'Бошед саломат'],
#    'responses': ['Хайр!', 'Руз ба хайр', 'То боздид!'],
#    'context': ['']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks',
#     'Thank you',
#     "That's helpful",
#     'Awesome, thanks',
#     'Thanks for helping me'],
#    'responses': ['Happy to help!', 'Any time!', 'My pleasure'],
#    'context': ['']},
#   {'tag': 'спасибо',
#    'patterns': ['Спасибо',
#     'Спасибо большое',
#     'Классно',
#     'Удивительно',
#     'Спасибо за помощь'],
#    'responses': ['Рад за помощь!', 'В любое время!', 'Не за что'],
#    'context': ['']},
#   {'tag': 'раҳмат',
#    'patterns': ['Раҳмат', 'Раҳмати калон', 'Зӯр', 'Аҳсан', 'Раҳмат ба ёрдам'],
#    'responses': ['Ӣоз муроҷиат намоед!', 'Саломат бошед!', 'Ҳеҷ гап не!'],
#    'context': ['']},
#   {'tag': 'noanswer',
#    'patterns': [],
#    'responses': ["Sorry, can't understand you",
#     'Please give me more info',
#     'Not sure I understand'],
#    'context': ['']},
#   {'tag': 'безответа',
#    'patterns': [],
#    'responses': ['Извините, я вас не понимаю',
#     'Предоставьте по больше информации',
#     'Не уверен, что я вас понимаю'],
#    'context': ['']},
#   {'tag': 'беҷавоб',
#    'patterns': [],
#    'responses': ['Бубахшед, ман шуморо нафахмидам',
#     'Бештар малумот пешниход намоед',
#     'Ман шуморо нафахмида истодаам'],
#    'context': ['']},
#   {'tag': 'options',
#    'patterns': ['How you could help me?',
#     'What you can do?',
#     'What help you provide?',
#     'How you can be helpful?',
#     'What support is offered'],
#    'responses': ['I can guide you through product list in pharmacy'],
#    'context': ['']},
#   {'tag': 'варианты',
#    'patterns': ['Как ты можешь мне помочь?',
#     'Что ты можешь сделать?',
#     'Какую помощь вы оказываете?',
#     'Как вы можете быть полезны?',
#     'Какая поддержка предлагается',
#     'Чем можешь помочь?'],
#    'responses': ['Я могу вам найти препарат в аптеке и подсказать цену'],
#    'context': ['']},
#   {'tag': 'вариантҳо',
#    'patterns': ['Чӣ хизмат кунам?',
#     'Чӣ кор карда метавонед?',
#     'Чӣ ёрдам карда метавонед?',
#     'Чӣ тавр ёри расонида метавонед?',
#     'Чӣ ёрдам лозим?',
#     'Чӣ кор мекунӣ?'],
#    'responses': ['Ман метавонам мавҷуд будани кадом дору ва нархи онро гӯям'],
#    'context': ['']},
#   {'tag': 'product_search',
#    'patterns': ['Find me a pill',
#     'Find medicament',
#     'List of medicaments in pharmacy',
#     'Search medicaments'],
#    'responses': ['Please provide product name'],
#    'context': ['search_product_by_name']},
#   {'tag': 'search_product_by_name',
#    'patterns': ['Абактал',
#     'Абактал',
#     'Абактал',
#     'Авамис',
#     'Авексон-рационал',
#     'Авексон-рационал',
#     'Аводарт',
#     'Аводарт',
#     'Авокадо',
#     'Аврора',
#     'Автопассит',
#     'Авторекс',
#     'Авторекс',
#     'Авторекс-А',
#     'Авторекс-А',
#     'Агри',
#     'Адамол',
#     'Адаптол',
#     'Адаптол',
#     'Адаптол',
#     'Адвантан',
#     'АджиСек',
#     'Аджисепт',
#     'Адикардин',
#     'Адонис-Бром',
#     'АЕвит',
#     'Аевит',
#     'Азатиоприн',
#     'Азафен',
#     'Азимак',
#     'Азимак',
#     'Азитромицин',
#     'Азитромицин',
#     'Азитромицин',
#     'Азитромицин',
#     'Азопт',
#     'Айдип',
#     'Аир',
#     'Аир',
#     'Айтон',
#     'Аква',
#     'Аква',
#     'Аквадетрим',
#     'АкваДетрим',
#     'Аквалор',
#     'Аквалор',
#     'Аквалор',
#     'Аквалор',
#     'Акизол-40',
#     'Акку-Чек',
#     'Акку-Чек',
#     'Акку-Чек',
#     'Акнеген',
#     'Акнекутан',
#     'Акнесол',
#     'Акнетрент',
#     'Акнетрент',
#     'Акнетрент',
#     'Акнетрент',
#     'Акнефаст',
#     'Акридерм',
#     'Акридерм',
#     'Акридерм',
#     'Акридон',
#     'Актовегин',
#     'Актовегин',
#     'Актовегин',
#     'Актовегин',
#     'Актовегин',
#     'Актовегин',
#     'Актовегин',
#     'Актрапид',
#     'Албаленс',
#     'Алвормин',
#     'Алгис',
#     'Алер',
#     'Алерана',
#     'Алерана',
#     'Алерана',
#     'Алергозол-DF',
#     'Алергозол-DF',
#     'Алергозол-DF',
#     'Алиса',
#     'Аллапинин',
#     'Аллева',
#     'Аллервег',
#     'Аллервег',
#     'Аллергодил',
#     'Аллокин-Альфа',
#     'Аллопуринол',
#     'Аллопуринол',
#     'Аллопуринол-ЭГИС',
#     'Аллохол',
#     'Аллохол',
#     'Алмавикс',
#     'Алмагель',
#     'Алмагель',
#     'Алоэ',
#     'Алоэ',
#     'Алоэ',
#     'Алтея',
#     'Алфавит',
#     'АлфаВит',
#     'Алфавит',
#     'Алфагин',
#     'Алфлутоп',
#     'Алфосид',
#     'Альбендазол',
#     'Альбумин',
#     'Альбунорм',
#     'Альфа',
#     'Альфа',
#     'Альфа',
#     'Амарил',
#     'Амарил',
#     'Амарил',
#     'Амарил',
#     'Амарил',
#     'Амбробене',
#     'Амбробене',
#     'Амбробин-ОФ',
#     'Амброкс',
#     'Амброксол',
#     'Амброксол',
#     'Амвастан',
#     'Амвастан',
#     'Амиаку',
#     'Амиаку',
#     'Амикацин',
#     'Амиксин',
#     'Амиксин',
#     'Аминалон',
#     'Аминалон',
#     'Аминовен',
#     'Аминовен',
#     'АминоВитам',
#     'Аминокапрон',
#     'Аминол',
#     'Аминол',
#     'Аминоплазмаль',
#     'Аминоплазмаль',
#     'Амитриптилин',
#     'Амитриптилин',
#     'Амлесса',
#     'Амлизект',
#     'Амлизект',
#     'Амлипин',
#     'Амлодипин',
#     'Амлодипин',
#     'Амлодипин',
#     'Амлодипин',
#     'Амлодипин-ЗТ',
#     'Амлодипин-прана',
#     'Амлокор',
#     'Амлокор-А',
#     'Амлокс',
#     'Амлокс',
#     'Амлокс',
#     'Аммифурин',
#     'Амод-10',
#     'Амод-5',
#     'Амокварт',
#     'Амокс-250',
#     'Амокс-500',
#     'Амоксиклав',
#     'Амоксиклав',
#     'Амоксиклав',
#     'Амоксиклав',
#     'Амоксиклав',
#     'Амоксициллин',
#     'Амоксициллин',
#     'Амоксициллин',
#     'Ампиокс',
#     'Ампиокс-Ауф',
#     'Ампиокс-Ауф',
#     'Ампициллин',
#     'Ампициллин',
#     'Ампициллин',
#     'Ампициллин',
#     'Ампициллин',
#     'Ампициллин',
#     'Ампициллин',
#     'Амприлан',
#     'Амприлан',
#     'Амприлан',
#     'Аналгон',
#     'Анальгин',
#     'Анальгин',
#     'Анальгин',
#     'Анальгин',
#     'Анальгин-Ультра',
#     'Анаприлин',
#     'Анаприлин',
#     'Анасеп',
#     'Анатоксин',
#     'Анаферон',
#     'Анаферон',
#     'Анаферон',
#     'Анаферон',
#     'АнвиМакс',
#     'Анвифен',
#     'Ангиозил',
#     'Ангисартан-25',
#     'Ангисартан-50',
#     'Анданте',
#     'Андерим',
#     'Андерим',
#     'Андерим',
#     'Андипал',
#     'Анестезол',
#     'Анис',
#     'Анис',
#     'Антигриппин',
#     'Антикамень',
#     'Антикамень',
#     'Антикамень',
#     'АнтиМигрен',
#     'АнтиОксДуо',
#     'АНТИполицай',
#     'Антисептический',
#     'Анузол-М',
#     'Апизартрон',
#     'Апизартрон',
#     'Апилак',
#     'Аптечка',
#     'Арбидол',
#     'Арбидол',
#     'Арбидол',
#     'Аргинин-Ликво',
#     'Аргосульфан',
#     'Аргосульфан',
#     'Аргумел',
#     'Аргумел',
#     'Аргумел',
#     'Арифон',
#     'Аркоксиа',
#     'Аркоксиа',
#     'Аркоксиа',
#     'Артишока',
#     'Артоксан',
#     'Артоксан',
#     'Артоксан',
#     'Артоксан',
#     'Артоксан',
#     'Артра',
#     'Артра',
#     'Артро-Актив',
#     'Артрокол',
#     'Артрокол',
#     'Артрокол',
#     'Артроцин',
#     'Арфазин',
#     'Асвитол',
#     'Асклезан',
#     'Аскорбин',
#     'Аскорбин',
#     'Аскорбин',
#     'Аскорбин',
#     'Аскорбин',
#     'Аскорутин',
#     'Аскорутин',
#     'Асмада',
#     'Аспаркам',
#     'Аспаркам',
#     'Аспиратор',
#     'Аспирин',
#     'Аспирин',
#     'Аспирин',
#     'Атаракс',
#     'Атенолол',
#     'Атифин',
#     'Аторвастатин',
#     'Аторвастатин',
#     'Аторвастатин',
#     'Аторвастатин',
#     'Аторвастатин',
#     'Аторис',
#     'Атрикан',
#     'Атропин',
#     'Атропин',
#     'АТФ',
#     'АТФ',
#     'Аугментин',
#     'Ауробин',
#     'Афалаза',
#     'Афобазол',
#     'Афобазол',
#     'Ахромин',
#     'Ацемагнил',
#     'Ацерумен',
#     'Ацетилсалицил',
#     'Ацефил',
#     'Ацикав',
#     'Ацикав',
#     'Ацикав',
#     'Ацикловир',
#     'Ацикловир',
#     'Ацикловир',
#     'Ацикловир',
#     'Ацикловир',
#     'Ацикловир',
#     'Ацикловир',
#     'Ацикловир-акрихин',
#     'Аципол',
#     'АЦЦ',
#     'АЦЦ',
#     'Аэролет',
#     'Аэртал',
#     'Аэртал',
#     'Бабочка',
#     'Багеда',
#     'Багеда',
#     'Базирон',
#     'Базирон',
#     'Байтач',
#     'Баклосан',
#     'Бактамед',
#     'Бактамед',
#     'Бактериофаг',
#     'Бактокс',
#     'Бактокс',
#     'Бактокс',
#     'Бактум',
#     'Бальзам',
#     'Бальзам',
#     'Бандаж',
#     'Бандаж',
#     'Бандаж',
#     'Бандаж',
#     'Банеоцин',
#     'Банеоцин',
#     'Банеоцин',
#     'Баралгин-уни',
#     'Баралгин-уни',
#     'Барселив',
#     'Барсукор',
#     'Батферон',
#     'Батферон',
#     'Баю-Бай',
#     'Бебикол',
#     'Бебирейк',
#     'Бейби',
#     'Бейбиспазм',
#     'Бейбиспазм',
#     'Бейк',
#     'Бекладейм',
#     'Беклазон',
#     'Беклазон',
#     'Беклометазон',
#     'Бекломил',
#     'Бековит',
#     'Белазидим',
#     'Белазидим',
#     'Беландж',
#     'Беландж',
#     'Беландж',
#     'Белара',
#     'Белара',
#     'Белацеф',
#     'Белдомакс',
#     'Белдомакс',
#     'Белирест',
#     'Белирест',
#     'Белкарнитин',
#     'Беллатаминал',
#     'Белмокси',
#     'Белосалик',
#     'Белосалик',
#     'Беневрон',
#     'Беневрон',
#     'Беневрон',
#     'Беневрон',
#     'Бензил',
#     'Бензилбензоат',
#     'Бензилбензоат',
#     'Бензилбензоат',
#     'Бенфи',
#     'Бепантен',
#     'Бепантен',
#     'Бепантен',
#     'Березы',
#     'Берлитион',
#     'Берлитион',
#     'Берлитион',
#     'Берлитион',
#     'Берлитион',
#     'Беродуал',
#     'Беродуал',
#     'Беротек',
#     'Беротек',
#     'Беррилакт',
#     'Бессмертник',
#     'Бестоксол',
#     'Бетадин',
#     'Бетадин',
#     'Беталок',
#     'Беталок',
#     'Бетасерк',
#     'Бетасерк',
#     'Бетасерк',
#     'Бетасерк-16',
#     'Бетривит',
#     'Бетропил',
#     'Бидоп',
#     'Бидоп',
#     'Билобил',
#     'Билобил',
#     'Бильтрицид',
#     'Бинт',
#     'Бинт',
#     'Бинт',
#     'Бинт',
#     'Биотредин',
#     'Биофикс',
#     'Бисакодил-Хемофарм',
#     'Бисептол',
#     'Бисептол',
#     'Бисептол',
#     'Бисовега',
#     'Бисовега',
#     'Бисовега',
#     'Бисопролол',
#     'Бисопролол',
#     'Бисопролол',
#     'Бисопролол',
#     'Бисопролол',
#     'Бифидумбактерин',
#     'Бифидумбактерин',
#     'Бифилиз',
#     'Бифиформ',
#     'Бициллин-3',
#     'Бициллин-3',
#     'Бициллин-5',
#     'Бициллин-5',
#     'Блемарен',
#     'Блефарогель',
#     'Блефарогель',
#     'Боботик',
#     'Боботик',
#     'Бодрин',
#     'Бодяга',
#     'Болнол',
#     'Болнол',
#     'Бонджигар',
#     'Бонкур',
#     'Борная',
#     'Боро',
#     'Боро',
#     'Боровая',
#     'Боровая',
#     'Боровая',
#     'Боярышник',
#     'Боярышника',
#     'Боярышника',
#     'Бренакс',
#     'Бренакс',
#     'Брикеза',
#     'Бримоптик',
#     'Бритомар',
#     'Бровенсин',
#     'Бромгексин',
#     'Бромгексин',
#     'Бромокриптин-рихтер',
#     'Бронхолитин',
#     'Бронхолитин',
#     'Бронхомакс',
#     'Бронхо-мунал',
#     'Бронхо-мунал',
#     'Бронхо-мунал',
#     'Бронхо-мунал',
#     'Брофекс',
#     'Будектон',
#     'Будектон',
#     'Буманол',
#     'Буманол',
#     'Бусерелин',
#     'Бускопан',
#     'Бускопан',
#     'Бутадион',
#     'Бутадион-OBL',
#     'Бутулка',
#     'Бэбисан',
#     'Бэбисан',
#     'Бэндомин',
#     'Бюлин',
#     'В-50',
#     'Вавеган',
#     'Вавеган',
#     'Вавеган',
#     'Вагимилт',
#     'Вазатор',
#     'Вазатор',
#     'Вазатор',
#     'Вазелин',
#     'Вазелиновое',
#     'Вазелиновое',
#     'Вазилип',
#     'Вазобрал',
#     'Вазонат',
#     'Вазонат',
#     'Вайфекс',
#     'Валерианы',
#     'Валерианы',
#     'Валерианы',
#     'Валерианы',
#     'Валз',
#     'Валидол',
#     'Валокордин',
#     'Валокордин',
#     'Валосердин',
#     'Валтрекс',
#     'Валтрекс',
#     'Вамелан',
#     'Вамелан',
#     'Вамлосет',
#     'Вамлосет',
#     'Вамлосет',
#     'Вамлосет',
#     'Ванкомицин',
#     'Ванкомицин',
#     'Варфарекс',
#     'Варфарекс',
#     'Варфарекс',
#     'Варфарин',
#     'Варфарин',
#     'Вата',
#     'Вата',
#     'Вата',
#     'Ватные',
#     'Ватные',
#     'Ватные',
#     'ВГ-5',
#     'Вегадерм',
#     'Вегадерм',
#     'Вегафлокс',
#     'Вегафлокс',
#     'Вегацеф',
#     'Везикар',
#     'Везикар',
#     'Везомни',
#     'Велкацин',
#     'Велкацин',
#     'Венарус',
#     'Венарус',
#     'Венарус',
#     'Венодиол',
#     'Венодиол',
#     'Верабез',
#     'Верабез',
#     'Вермокс',
#     'Верона',
#     'Верона',
#     'Верошпирон',
#     'Верошпирон',
#     'Верошпирон',
#     'Веррукацид',
#     'Верта',
#     'Верта',
#     'Вессел',
#     'Вессел',
#     'Вестибо',
#     'Вестибо',
#     'Виадор',
#     'Виардо',
#     'Виардо',
#     'Виброцил',
#     'ВиваБон',
#     'Вигантол',
#     'ВизиДол',
#     'ВизиДол',
#     'Визиолайт',
#     'Визомитин',
#     'Викаир',
#     'Викаир',
#     'Викалин',
#     'Викасол',
#     'Викс',
#     'Вильпрафен',
#     'Вильпрафен',
#     'Винилин',
#     'Винпоцетин',
#     'Винпоцетин',
#     'Виплактин',
#     'Випрелакс',
#     'Випрелакс',
#     'Випрелакс',
#     'Випросал',
#     'Виратон',
#     'Вирпас',
#     'Вит',
#     'Вит',
#     'Вита',
#     'Вита',
#     'Витакалис',
#     'ВитаЛонг',
#     'ВитАмЕн',
#     'Витамин',
#     'Витамин',
#     'Витамин',
#     'Витамин',
#     'Витамин',
#     'Витамин',
#     'Витамин',
#     'Витамин',
#     'Витамин',
#     'Витамин',
#     'Витамин',
#     'Витамины',
#     'Витанол',
#     'Витапрост',
#     'Витапрост',
#     'Витапрост',
#     'Витапрост',
#     'Витапрост',
#     'Витапрост',
#     'Витаспей',
#     'Витаспей',
#     'Витаспей',
#     'Витацинк',
#     'Вито',
#     'Вито',
#     'Вито',
#     'Вито',
#     'Вито',
#     'Витрозит',
#     'Витрум',
#     'Виферон',
#     'Виферон',
#     'Виферон',
#     'Виферон',
#     'Виферон',
#     'Виферон',
#     'Виферон',
#     'Вишневский',
#     'Вишневский',
#     'В-Макс',
#     'В-Норм',
#     'Воби',
#     'Вобилон',
#     'Вобилон',
#     'Вовенак',
#     'Вовенак',
#     'Вода',
#     'Возбуд.',
#     'Возбуд.',
#     'Возбуд.',
#     'Возбуд.',
#     'Возбуд.',
#     'Вольтарен',
#     'Вольтарен',
#     'Вольтарен',
#     'Вольтарен',
#     'Вольтарен',
#     'Вольтарен',
#     'Вольтарен',
#     'Вольфуран',
#     'Вомилан',
#     'Враггрипп',
#     'Враггрипп',
#     'Врагдиарея',
#     'Газ',
#     'Галавит',
#     'Галавит',
#     'Галавит',
#     'Галазолин',
#     'Галазолин',
#     'Галантамин',
#     'Галвус',
#     'Галвус',
#     'Галвус',
#     'Галвус',
#     'Галвус',
#     'Галекс',
#     'Галекс',
#     'Гастал',
#     'Гварденс',
#     'Гварденс',
#     'Гварденс',
#     'Гварденс',
#     'Гду',
#     'Гевискон',
#     'Геделикс',
#     'Гексикон',
#     'Гексол',
#     'Гексол',
#     'Гексорал',
#     'Гексорал',
#     'Гексорал',
#     'Гелмадол',
#     'Гелофузин',
#     'Гелофузин',
#     'Гелоцер',
#     'Гель',
#     'Гельминтокс',
#     'Гельминтокс',
#     'Гельминтокс',
#     'Гематоген',
#     'Гематоген',
#     'Гемодез-8000',
#     'Гемодез-Н',
#     'ГемоСол',
#     'ГемоСол',
#     'ГемоСол',
#     'Гентаксан',
#     'Гентамицин',
#     'Гентамицин-К',
#     'Гентамицин-К',
#     'Генферон',
#     'Генферон',
#     'Гепакюр',
#     'Гепа-мерц',
#     'Гепа-Мерц',
#     'Гепариновая',
#     'Гепариновая',
#     'Гепатрав',
#     'Гепатрав',
#     'Гепатрин',
#     'Гептрал',
#     'Гептрал',
#     'Герал',
#     'Герветин',
#     'Герветин',
#     'Гиалуроновая',
#     'Гигиен',
#     'Гигиенич',
#     'Гидреа',
#     'Гидреа',
#     'Гидрокортизон',
#     'Гидрокортизон',
#     'Гинелайф',
#     'Гинипрал',
#     'Гинкго',
#     'Гинковег',
#     'Гинкоум',
#     'Гино',
#     'Гинобелс',
#     'Гинодек',
#     'Гиножинакс',
#     'Гинолактоспей',
#     'Гино-Микозал',
#     'Гинорал-Ф',
#     'ГинофорТ',
#     'Гиповин',
#     'Гипотиазид',
#     'Гипотиазид',
#     'Гипотрекс',
#     'Гистафен',
#     'Глазакор',
#     'Глазакор',
#     'Глиатилин',
#     'Глиатилин',
#     'Глиатилин',
#     'Глиатилин',
#     'Гликальце',
#     'Глимерик',
#     'Глина',
#     'Глисайт',
#     'Глицевит',
#     'Глицелакс',
#     'Глицерин',
#     'Глицерин',
#     'Глицерин',
#     'Глицин',
#     'Глицин',
#     'Глицин-Био',
#     'Глобавикс',
#     'Глобакт-С',
#     'Глобакт-С',
#     'Глониз',
#     'Глочек-Л',
#     'Глутаминова',
#     'Глутаминова',
#     'Глюкованс',
#     'Глюкованс',
#     'Глюкоза',
#     'Глюкоза',
#     'Глюкоза',
#     'Глюкоза',
#     'Глюкоза',
#     'Глюкоза',
#     'Глюкоза',
#     'Глюкоза',
#     'Глюкозамин+Хондроитин',
#     'Глюкорекс-В',
#     'Глюкотон-MR',
#     'Глюкофаж',
#     'Глюкофаж',
#     'Глюкофаж',
#     'Глюкофаж',
#     'Глюкофаж',
#     'Глюкофаж',
#     'Глюкофаж',
#     'Глюкофаж',
#     'Глюренорм',
#     'Глюренорм',
#     'Глютаминовая',
#     'Голаксин',
#     'Голаксин',
#     'Голд',
#     'Голд',
#     'Гольфы',
#     'Гонадот.Хорион',
#     'Гонадотропин',
#     'Гонадотропин',
#     'Гонадотропин',
#     'Гонал-ф',
#     'Гонал-Ф',
#     'Гордокс',
#     'Горный',
#     'Горчичный',
#     'Горчичный',
#     'Граммидин',
#     'Грандаксин',
#     'Грелка',
#     'Гриппалек',
#     'Гриппферон',
#     'Гриппферон',
#     'Грицен',
#     'Гроприносин',
#     'Гроприносин-Рихтер',
#     'Грудасос',
#     'Гутталакс',
#     'Гутталакс',
#     'Даверис',
#     'Даверис',
#     'Далавит-300',
#     'Далацин',
#     'Далацин',
#     'Далацин',
#     'Дамфос',
#     'Даназол',
#     'Дапоксетин-К',
#     'Движекс',
#     'Дебара',
#     'Девясил',
#     'Девясил',
#     'Деготь',
#     'Деготь',
#     'Дегтярное',
#     'Дезаминоокситоцин',
#     'Декарис',
#     'Декарис',
#     'Декасан',
#     'Деклосид',
#     'Деклосид',
#     'Дексалгин',
#     'Дексалгин',
#     'Дексаметазон',
#     'Дексаметазон',
#     'Дексанем',
#     'Дексин',
#     'Декстрорил',
#     'Декстрорил',
#     'Делагил',
#     'Демазол',
#     'Демоквел',
#     'Демотон-Б',
#     'Демотон-Б',
#     'Демотон-Т',
#     'Де-Нол',
#     'Денташан',
#     'Депакин',
#     'Депакин',
#     'Депакин',
#     'Депиляторный',
#     'Депосилин',
#     'Деревенс',
#     'Деревенс',
#     'Дерилайф',
#     'Деринат',
#     'Дермазол',
#     'Дермазол',
#     'Дермазол',
#     'Дерматикс',
#     'Дермовейт',
#     'Десмекс',
#     'Десмекс',
#     'Десмопрессин',
#     'Десолайт',
#     'Детоксик',
#     'Детралекс',
#     'Детралекс',
#     'Деятекс',
#     'Джес',
#     'Джигарин',
#     'Джонсон',
#     'Джонсон',
#     'Джонсон',
#     'Диабетон',
#     'Диабетон',
#     'Диабефарм',
#     'ДиаДерм',
#     'ДиаДерм',
#     'Диазолин',
#     'Диазолин',
#     'Диазолин',
#     'Диакарб',
#     'Диалин-М',
#     'Диане',
#     'Дианейро',
#     'Диафор',
#     'Дибазол',
#     'Дибазол',
#     'Дивлаксин',
#     'Дигестин',
#     'Дигидрокверцетин',
#     'Дигидротахистерол',
#     'Дигоксин',
#     'Дигоксин',
#     'Дигоксин',
#     'Дикловит',
#     'Диклокор',
#     'Диклопар',
#     'Диклопар',
#     'Диклоран',
#     'Диклофенак',
#     'Диклофенак',
#     'Диклофенак',
#     'Диклофенак',
#     'Диклофенак',
#     'Диклофенак',
#     'Диконим',
#     'Дикортан',
#     'Дилтиазем',
#     'Дилтиазем',
#     'Дилтиазем',
#     'Димедрол',
#     'Димедрол',
#     'Димедрол',
#     'Димексид',
#     'Димиа',
#     'Диоксидин',
#     'Диоксидин',
#     'Диосперидин',
#     'Дип',
#     'Дипросалик',
#     'Дипроспан',
#     'Диронест',
#     'Диротон',
#     'Диротон',
#     'Дискус',
#     'Дистрептаза',
#     'Дитреф',
#     'Диувер',
#     'Дифекс',
#     'Дифекс',
#     'Диферол',
#     'Дифлюкан',
#     'Дифлюкан',
#     'Дифунгин',
#     'Дифферин',
#     'Дифферин',
#     'Дицетел',
#     'Дицинон',
#     'Дицинон',
#     'Добутамин',
#     'Дозипресс-Т',
#     'Док-1',
#     'Док-1',
#     'Док-1',
#     'Доксициклин',
#     'Доксициклин',
#     'Доктор',
#     'Доктор',
#     'Доктор',
#     'Доктор',
#     'Доктор',
#     'Доктор',
#     'Долгит',
#     'Долейка',
#     'Долейка',
#     'Долобене',
#     'Долфин',
#     'Долфин',
#     'Дона',
#     'Дона',
#     'Дона',
#     'Донормил',
#     'Допамин',
#     'Допегит',
#     'Доплет-3',
#     'Допрокин',
#     'Допрокин-С',
#     'Допрокин-С',
#     'Дорамицин',
#     'Дорзамед',
#     'Дорзасопт',
#     'Достинекс',
#     'Драйдрай',
#     'Драйдрай',
#     'Драйдрай',
#     'Драматек',
#     'Драматек-С',
#     'Драмина',
#     'Драстоп',
#     'Дриптан',
#     'Дроплекс',
#     'Дротаверина-гидрозлорид',
#     'Дуовит',
#     'Дуовит',
#     ...],
#    'responses': ['Yes'],
#    'context': ['']}]}

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kurbonovf\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# **2. Preprocess data**
#
# When working with text data, we need to perform various preprocessing on the data before we make a machine learning or a deep learning model. Based on the requirements we need to apply various operations to preprocess the data.
#
# Tokenizing is the most basic and first thing you can do on text data. Tokenizing is the process of breaking the whole text into small parts like words.
#
# Here we iterate through the patterns and tokenize the sentence using nltk.word_tokenize() function and append each word in the words list. We also create a list of classes for our tags.

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kurbonovf\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# Now we will lemmatize each word and remove duplicate words from the list. Lemmatizing is the process of converting a word into its lemma form and then creating a pickle file to store the Python objects which we will use while predicting.

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 3572 documents
# 14 classes ['goodbye', 'greeting', 'options', 'product_search', 'search_product_by_name', 'thanks', 'варианты', 'вариантҳо', 'пока', 'привет', 'раҳмат', 'салом', 'спасибо', 'хайр']
# 2261 unique lemmatized words ["'s", '(', ')', ',', '.', 'a', 'anyone', 'are', 'awesome', 'be', 'bye', 'can', 'chatting', 'could', 'day', 'do', 'find', 'for', 'good', 'goodbye', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'hola', 'how', 'in', 'is', 'later', 'list', 'me', 'medicament', 'next', 'nice', 'of', 'offered', 'pharmacy', 'pill', 'provide', 'search', 'see', 'support', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'what', 'you', 'абактал', 'авамис', 'авексон-рационал', 'аводарт', 'авокадо', 'аврора', 'автопассит', 'авторекс', 'авторекс-а', 'агри', 'адамол', 'адаптол', 'адвантан', 'аджисек', 'аджисепт', 'адикардин', 'адонис-бром', 'аевит', 'азатиоприн', 'азафен', 'азимак', 'азитромицин', 'азопт', 'аир', 'айдип', 'айтон', 'аква', 'аквадетрим', 'аквалор', 'акизол-40', 'акку-чек', 'акнеген', 'акнекутан', 'акнесол', 'акнетрент', 'акнефаст', 'акридерм', 'акридон', 'актовегин', 'актрапид', 'албаленс', 'алвормин', 'алгис', 'алейкум', 'алер', 'алерана', 'алергозол-df', 'алиса', 'аллапинин', 'аллева', 'аллервег', 'аллергодил', 'алло', 'аллокин-альфа', 'аллопуринол', 'аллопуринол-эгис', 'аллохол', 'алмавикс', 'алмагель', 'алоэ', 'алтея', 'алфавит', 'алфагин', 'алфлутоп', 'алфосид', 'альбендазол', 'альбумин', 'альбунорм', 'альфа', 'амарил', 'амбробене', 'амбробин-оф', 'амброкс', 'амброксол', 'амвастан', 'амиаку', 'амикацин', 'амиксин', 'аминалон', 'аминовен', 'аминовитам', 'аминокапрон', 'аминол', 'аминоплазмаль', 'амитриптилин', 'амлесса', 'амлизект', 'амлипин', 'амлодипин', 'амлодипин-зт', 'амлодипин-прана', 'амлокор', 'амлокор-а', 'амлокс', 'аммифурин', 'амод-10', 'амод-5', 'амокварт', 'амокс-250', 'амокс-500', 'амоксиклав', 'амоксициллин', 'ампиокс', 'ампиокс-ауф', 'ампициллин', 'амприлан', 'аналгон', 'анальгин', 'анальгин-ультра', 'анаприлин', 'анасеп', 'анатоксин', 'анаферон', 'анвимакс', 'анвифен', 'ангиозил', 'ангисартан-25', 'ангисартан-50', 'анданте', 'андерим', 'андипал', 'анестезол', 'анис', 'антигриппин', 'антикамень', 'антимигрен', 'антиоксдуо', 'антиполицай', 'антисептический', 'анузол-м', 'апизартрон', 'апилак', 'аптечка', 'арбидол', 'аргинин-ликво', 'аргосульфан', 'аргумел', 'арифон', 'аркоксиа', 'артишока', 'артоксан', 'артра', 'артро-актив', 'артрокол', 'артроцин', 'арфазин', 'асвитол', 'асклезан', 'аскорбин', 'аскорутин', 'асмада', 'аспаркам', 'аспиратор', 'аспирин', 'ассалому', 'атаракс', 'атенолол', 'атифин', 'аторвастатин', 'аторис', 'атрикан', 'атропин', 'атф', 'аугментин', 'ауробин', 'афалаза', 'афобазол', 'ахромин', 'ацемагнил', 'ацерумен', 'ацетилсалицил', 'ацефил', 'ацикав', 'ацикловир', 'ацикловир-акрихин', 'аципол', 'ацц', 'аэролет', 'аэртал', 'аҳсан', 'ба', 'бабочка', 'багеда', 'базирон', 'байтач', 'баклосан', 'бактамед', 'бактериофаг', 'бактокс', 'бактум', 'бальзам', 'бандаж', 'банеоцин', 'баралгин-уни', 'барселив', 'барсукор', 'батферон', 'баю-бай', 'бебикол', 'бебирейк', 'бейби', 'бейбиспазм', 'бейк', 'бекладейм', 'беклазон', 'беклометазон', 'бекломил', 'бековит', 'белазидим', 'беландж', 'белара', 'белацеф', 'белдомакс', 'белирест', 'белкарнитин', 'беллатаминал', 'белмокси', 'белосалик', 'беневрон', 'бензил', 'бензилбензоат', 'бенфи', 'бепантен', 'березы', 'берлитион', 'беродуал', 'беротек', 'беррилакт', 'бессмертник', 'бестоксол', 'бетадин', 'беталок', 'бетасерк', 'бетасерк-16', 'бетривит', 'бетропил', 'бидоп', 'билобил', 'бильтрицид', 'бинт', 'биотредин', 'биофикс', 'бисакодил-хемофарм', 'бисептол', 'бисовега', 'бисопролол', 'бифидумбактерин', 'бифилиз', 'бифиформ', 'бициллин-3', 'бициллин-5', 'блемарен', 'блефарогель', 'боботик', 'бодрин', 'бодяга', 'боздид', 'болнол', 'большое', 'бонджигар', 'бонкур', 'борная', 'боро', 'боровая', 'бошед', 'боярышник', 'боярышника', 'бренакс', 'брикеза', 'бримоптик', 'бритомар', 'бровенсин', 'бромгексин', 'бромокриптин-рихтер', 'бронхо-мунал', 'бронхолитин', 'бронхомакс', 'брофекс', 'будектон', 'буманол', 'бусерелин', 'бускопан', 'бутадион', 'бутадион-obl', 'бутулка', 'было', 'быть', 'бэбисан', 'бэндомин', 'бюлин', 'в-50', 'в-макс', 'в-норм', ' ...

# %% [markdown]
# **3. Create training and testing data**
#
# Now, we will create the training data in which we will provide the input and the output. Our input will be the pattern and output will be the class our input pattern belongs to. But the computer doesn’t understand text so we will convert text into numbers.

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %% [markdown]
# **4. Build the model**
#
# We have our training data ready, now we will build a deep neural network that has 3 layers. We use the Keras sequential API for this. After training the model for 200 epochs, we achieved 100% accuracy on our model. Let us save the model as ‘chatbot_model.h5’.

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model created")
# Out:
# Epoch 1/200
# 715/715 [==============================] - 3s 3ms/step - loss: 0.2123 - accuracy: 0.9773
# Epoch 2/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.1506 - accuracy: 0.9798
# Epoch 3/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.1293 - accuracy: 0.9798
# Epoch 4/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.1148 - accuracy: 0.9801
# Epoch 5/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0960 - accuracy: 0.9804
# Epoch 6/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0855 - accuracy: 0.9801
# Epoch 7/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0663 - accuracy: 0.9815
# Epoch 8/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0615 - accuracy: 0.9826
# Epoch 9/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0557 - accuracy: 0.9815
# Epoch 10/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0508 - accuracy: 0.9826
# Epoch 11/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0485 - accuracy: 0.9832
# Epoch 12/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0504 - accuracy: 0.9849
# Epoch 13/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0459 - accuracy: 0.9852
# Epoch 14/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0460 - accuracy: 0.9863
# Epoch 15/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0434 - accuracy: 0.9860
# Epoch 16/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0440 - accuracy: 0.9860
# Epoch 17/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0400 - accuracy: 0.9877
# Epoch 18/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0396 - accuracy: 0.9868
# Epoch 19/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0380 - accuracy: 0.9882
# Epoch 20/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0364 - accuracy: 0.9888
# Epoch 21/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0348 - accuracy: 0.9894
# Epoch 22/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0373 - accuracy: 0.9891
# Epoch 23/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0322 - accuracy: 0.9899
# Epoch 24/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0315 - accuracy: 0.9902
# Epoch 25/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0299 - accuracy: 0.9910
# Epoch 26/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0284 - accuracy: 0.9908
# Epoch 27/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0272 - accuracy: 0.9922
# Epoch 28/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0242 - accuracy: 0.9922
# Epoch 29/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0291 - accuracy: 0.9916
# Epoch 30/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0283 - accuracy: 0.9916
# Epoch 31/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0186 - accuracy: 0.9961
# Epoch 32/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0158 - accuracy: 0.9961
# Epoch 33/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0180 - accuracy: 0.9961
# Epoch 34/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0179 - accuracy: 0.9936
# Epoch 35/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0154 - accuracy: 0.9958
# Epoch 36/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0172 - accuracy: 0.9950
# Epoch 37/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0146 - accuracy: 0.9955
# Epoch 38/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0152 - accuracy: 0.9961
# Epoch 39/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0175 - accuracy: 0.9947
# Epoch 40/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0141 - accuracy: 0.9952
# Epoch 41/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0131 - accuracy: 0.9964
# Epoch 42/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0152 - accuracy: 0.9947
# Epoch 43/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0113 - accuracy: 0.9969
# Epoch 44/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0115 - accuracy: 0.9969
# Epoch 45/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0121 - accuracy: 0.9975
# Epoch 46/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0128 - accuracy: 0.9966
# Epoch 47/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0113 - accuracy: 0.9969
# Epoch 48/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0099 - accuracy: 0.9972
# Epoch 49/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0108 - accuracy: 0.9966
# Epoch 50/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0083 - accuracy: 0.9978
# Epoch 51/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0100 - accuracy: 0.9975
# Epoch 52/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0113 - accuracy: 0.9966
# Epoch 53/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0098 - accuracy: 0.9972
# Epoch 54/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0079 - accuracy: 0.9969
# Epoch 55/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0068 - accuracy: 0.9980
# Epoch 56/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0076 - accuracy: 0.9983
# Epoch 57/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0064 - accuracy: 0.9983
# Epoch 58/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0059 - accuracy: 0.9986
# Epoch 59/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0066 - accuracy: 0.9983
# Epoch 60/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0066 - accuracy: 0.9986
# Epoch 61/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0059 - accuracy: 0.9983
# Epoch 62/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0063 - accuracy: 0.9986
# Epoch 63/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0053 - accuracy: 0.9989
# Epoch 64/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0044 - accuracy: 0.9992
# Epoch 65/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0052 - accuracy: 0.9989
# Epoch 66/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0044 - accuracy: 0.9983
# Epoch 67/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0037 - accuracy: 0.9994
# Epoch 68/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0046 - accuracy: 0.9994
# Epoch 69/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0053 - accuracy: 0.9983
# Epoch 70/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0058 - accuracy: 0.9986
# Epoch 71/200
# 715/715 [==============================] - 2s 2ms/step - loss: 0.0035 - accuracy: 0.9994
# Epoch 72/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0047 - accuracy: 0.9989
# Epoch 73/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0064 - accuracy: 0.9983
# Epoch 74/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0036 - accuracy: 0.9992
# Epoch 75/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0043 - accuracy: 0.9992
# Epoch 76/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0044 - accuracy: 0.9986
# Epoch 77/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0041 - accuracy: 0.9989
# Epoch 78/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0043 - accuracy: 0.9983
# Epoch 79/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0052 - accuracy: 0.9978
# Epoch 80/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0060 - accuracy: 0.9980
# Epoch 81/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0043 - accuracy: 0.9989
# Epoch 82/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0058 - accuracy: 0.9986
# Epoch 83/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0043 - accuracy: 0.9989
# Epoch 84/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0032 - accuracy: 0.9994
# Epoch 85/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 86/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0047 - accuracy: 0.9986
# Epoch 87/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 88/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0037 - accuracy: 0.9994
# Epoch 89/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 90/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 91/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0067 - accuracy: 0.9986
# Epoch 92/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0056 - accuracy: 0.9989
# Epoch 93/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0036 - accuracy: 0.9983
# Epoch 94/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0017 - accuracy: 0.9997
# Epoch 95/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0025 - accuracy: 0.9994
# Epoch 96/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0038 - accuracy: 0.9986
# Epoch 97/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0024 - accuracy: 0.9997
# Epoch 98/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 99/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0043 - accuracy: 0.9992
# Epoch 100/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0046 - accuracy: 0.9983
# Epoch 101/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0033 - accuracy: 0.9994
# Epoch 102/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0044 - accuracy: 0.9986
# Epoch 103/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0060 - accuracy: 0.9980
# Epoch 104/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0071 - accuracy: 0.9972
# Epoch 105/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 106/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0033 - accuracy: 0.9994
# Epoch 107/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0039 - accuracy: 0.9983
# Epoch 108/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0035 - accuracy: 0.9994
# Epoch 109/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0027 - accuracy: 0.9994
# Epoch 110/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0032 - accuracy: 0.9992
# Epoch 111/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0028 - accuracy: 0.9994
# Epoch 112/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0034 - accuracy: 0.9986
# Epoch 113/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0027 - accuracy: 0.9992
# Epoch 114/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0027 - accuracy: 0.9997
# Epoch 115/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 116/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 117/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0021 - accuracy: 0.9992
# Epoch 118/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 119/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 120/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 121/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 122/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0015 - accuracy: 0.9997
# Epoch 123/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 124/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0022 - accuracy: 0.9989
# Epoch 125/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0039 - accuracy: 0.9989
# Epoch 126/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0040 - accuracy: 0.9989
# Epoch 127/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0021 - accuracy: 0.9997
# Epoch 128/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 129/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0059 - accuracy: 0.9980
# Epoch 130/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0024 - accuracy: 0.9989
# Epoch 131/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0034 - accuracy: 0.9983
# Epoch 132/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0042 - accuracy: 0.9992
# Epoch 133/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 134/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0024 - accuracy: 0.9989
# Epoch 135/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0037 - accuracy: 0.9989
# Epoch 136/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0043 - accuracy: 0.9983
# Epoch 137/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 138/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0021 - accuracy: 0.9992
# Epoch 139/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0028 - accuracy: 0.9994
# Epoch 140/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0017 - accuracy: 0.9992
# Epoch 141/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 142/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0028 - accuracy: 0.9994
# Epoch 143/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 144/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 145/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0018 - accuracy: 0.9992
# Epoch 146/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0021 - accuracy: 0.9992
# Epoch 147/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0025 - accuracy: 0.9994
# Epoch 148/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0012 - accuracy: 0.9994
# Epoch 149/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0021 - accuracy: 0.9992
# Epoch 150/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0019 - accuracy: 0.9992
# Epoch 151/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0041 - accuracy: 0.9980
# Epoch 152/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 0.9992
# Epoch 153/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0027 - accuracy: 0.9989
# Epoch 154/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0013 - accuracy: 0.9994
# Epoch 155/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 156/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0013 - accuracy: 0.9997
# Epoch 157/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0022 - accuracy: 0.9992
# Epoch 158/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0021 - accuracy: 0.9997
# Epoch 159/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0038 - accuracy: 0.9983
# Epoch 160/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 161/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 0.9997
# Epoch 162/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0017 - accuracy: 0.9997
# Epoch 163/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0020 - accuracy: 0.9997
# Epoch 164/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0027 - accuracy: 0.9989
# Epoch 165/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 166/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0034 - accuracy: 0.9994
# Epoch 167/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 168/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0025 - accuracy: 0.9997
# Epoch 169/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0029 - accuracy: 0.9992
# Epoch 170/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0030 - accuracy: 0.9994
# Epoch 171/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 0.9997
# Epoch 172/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 173/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 174/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0014 - accuracy: 0.9997
# Epoch 175/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 176/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0014 - accuracy: 0.9997
# Epoch 177/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0020 - accuracy: 0.9989
# Epoch 178/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 179/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0027 - accuracy: 0.9992
# Epoch 180/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0021 - accuracy: 0.9989
# Epoch 181/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 182/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0019 - accuracy: 0.9989
# Epoch 183/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0015 - accuracy: 0.9997
# Epoch 184/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 185/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0013 - accuracy: 0.9994
# Epoch 186/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 187/200
# 715/715 [==============================] - 2s 3ms/step - loss: 8.1168e-04 - accuracy: 0.9997
# Epoch 188/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 189/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0034 - accuracy: 0.9992
# Epoch 190/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 191/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 192/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0023 - accuracy: 0.9997
# Epoch 193/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 194/200
# 715/715 [==============================] - 2s 3ms/step - loss: 0.0012 - accuracy: 0.9997
# Epoch 195/200
# 715/715 [==============================] - 4s 5ms/step - loss: 0.0014 - accuracy: 0.9997
# Epoch 196/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0018 - accuracy: 0.9994
# Epoch 197/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 198/200
# 715/715 [==============================] - 3s 4ms/step - loss: 0.0010 - accuracy: 0.9997
# Epoch 199/200
# 715/715 [==============================] - 3s 3ms/step - loss: 0.0022 - accuracy: 0.9989
# Epoch 200/200
# 715/715 [==============================] - 2s 3ms/step - loss: 9.5392e-04 - accuracy: 1.0000
# model created

# %% [markdown]
# **5. Predict the response (Graphical User Interface)**
#
#
# To predict the sentences and get a response from the user to let us code the following.
#
# We will load the trained model and then use a graphical user interface that will predict the response from the bot. The model will only tell us the class it belongs to, so we will implement some functions which will identify the class and then retrieve us a random response from the list of responses.
#
# Again we import the necessary packages and load the ‘words.pkl’ and ‘classes.pkl’ pickle files which we have created when we trained our model:

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents_tj_ru.json', encoding="utf8").read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %% [markdown]
# To predict the class, we will need to provide input in the same way as we did while training. So we will create some functions that will perform text preprocessing and then predict the class.

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %% [markdown]
# We read the medicaments from Excel file. The excel file was extracted using pharmacy software which is developed in C# by our company.

# %%
from pathlib import Path
import openpyxl

data = {}

def read_xls():
    xlsx_file = Path('C:\Other\HSE\Course\ML Project\chatbot-python-project-data-codes', 'Product.xlsx')
    wb_obj = openpyxl.load_workbook(xlsx_file) 

    # Read the active sheet:
    sheet = wb_obj.active

    for i, row in enumerate(sheet.iter_rows(values_only=True)):
        if i == 0:
            data['Product'] = []
            data['Quantity'] = []
            data['Price'] = []
            data['DueTo'] = []
            data['Manufacturer'] = []
        else:
            data['Product'].append(row[0])
            data['Quantity'].append(row[2])
            data['Price'].append(row[3])
            data['DueTo'].append(row[4])
            data['Manufacturer'].append(row[5])

    return data

# %% [markdown]
# After predicting the class, we will get a random response from the list of intents.

# %%
def getResponse(ints, intents_json, text):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']=="search_product_by_name"):
            result = search_by_name(text)
            break        
        elif(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents, text)
    return res

def search_by_name(text):
    read_xls()
    for i in range(len(data['Product'])):
        if data['Product'][i] == text:
            return "Наименование: "+data['Product'][i] + "  Количество: "+str(data['Quantity'][i]) + "  Цена: "+str(data['Price'][i]) + " сомони" + "  Срок годности: "+data['DueTo'][i].strftime('%d-%m-%Y') + "  Производитель: "+str(data['Manufacturer'][i])
        elif i==len(data['Product'])-1:
            return "Не нашёл запрашиваемый препарат, попробуйте другое наименование препарата"

# %% [markdown]
# Now we will develop a graphical user interface. Let’s use Tkinter library which is shipped with tons of useful libraries for GUI. We will take the input message from the user and then use the helper functions we have created to get the response from the bot and display it on the GUI. Here is the full source code for the GUI.

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()

# %% [markdown]
# The program will open up a GUI window within a few seconds. With the GUI you can easily chat with the bot.

# %% [markdown]
# ## Summary
# In this project, we understood about chatbots and implemented a deep learning version of a chatbot in Python which is accurate. You can customize the data according to business requirements and train the chatbot with great accuracy. Chatbots are used everywhere and all businesses are looking forward to implementing bot in their workflow.
